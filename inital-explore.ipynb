# %%
import pandas as pd
import prepare
from prepare import random_sample
from prepare import prepare_abstracts_for_nlp
# Out:
# [nltk_data] Downloading package punkt to /home/andrew/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/andrew/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/andrew/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/andrew/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/andrew/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/andrew/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/andrew/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %% [markdown]
# | Column Name      | Data Type     | Description                                                                                                                                            |
# | ---------------- | ------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | `id`             | string        | Unique identifier assigned to each paper on arXiv (e.g., `0704.0001`). Can be used to construct URLs to the paper.                                     |
# | `submitter`      | string        | Name of the individual who submitted the paper to arXiv (not necessarily the first author).                                                            |
# | `authors`        | string        | Raw, comma-separated list of authors as a single text field.                                                                                           |
# | `authors_parsed` | list of lists | Structured representation of authors in the format `[Last Name, First Name(s), Suffix]`.                                                               |
# | `title`          | string        | Title of the research paper.                                                                                                                           |
# | `abstract`       | string        | Full abstract of the paper.                                                                                                                            |
# | `categories`     | string        | Space-separated list of subject categories assigned by arXiv (e.g., `cs.AI`, `math.CO`). The first category is considered the primary classification.  |
# | `comments`       | string / null | Optional author-provided comments (e.g., number of pages, figures, publication notes).                                                                 |
# | `journal-ref`    | string / null | Reference to the journal where the paper was published, if applicable.                                                                                 |
# | `doi`            | string / null | Digital Object Identifier linking to the published version of the paper.                                                                               |
# | `report-no`      | string / null | Institutional or technical report number associated with the paper.                                                                                    |
# | `license`        | string / null | URL specifying the licensing terms under which the paper is distributed.                                                                               |
# | `versions`       | list of dicts | List of version records, each containing version number and submission date (e.g., `v1`, `v2`).                                                        |
# | `update_date`    | string (date) | Date of the most recent update to the paper in `YYYY-MM-DD` format.                                                                                    |

# %%
random_sample()

# %%
df = pd.read_parquet('./arxiv_sample.parquet')

# %%
df.head()
# Out:
#           id           submitter                                    authors  \
# 0  0704.0002        Louis Theran            Ileana Streinu and Louis Theran
# 1  0704.0008        Damian Swift                            Damian C. Swift
# 2  0704.0010  Sergei Ovchinnikov                         Sergei Ovchinnikov
# 3  0704.0013         Dohoon Choi              Dohoon Choi and YoungJu Choie
# 4  0704.0020     Patrick Roudeau  The BABAR Collaboration, B. Aubert, et al
#
#                                                title  \
# 0           Sparsity-certifying Graph Decompositions
# 1  Numerical solution of shock and ramp compressi...
# 2  Partial cubes: structures, characterizations, ...
# 3  $p$-adic Limit of Weakly Holomorphic Modular F...
# 4  Measurement of the Hadronic Form Factor in D0 ...
#
#                                             comments  \
# 0              To appear in Graphs and Combinatorics
# 1                                  Minor corrections
# 2                               36 pages, 17 figures
# 3                                                NaN
# 4  21 pages, 13 postscript figures, submitted to ...
#
#                                          journal-ref  \
# 0                                                NaN
# 1  Journal of Applied Physics, vol 104, 073536 (2...
# 2                                                NaN
# 3                                                NaN
# 4                           Phys.Rev.D76:052005,2007
#
#                           doi                         report-no  \
# 0                         NaN                               NaN
# 1           10.1063/1.2975338   LA-UR-07-2051, LLNL-JRNL-410358
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4  10.1103/PhysRevD.76.052005  BABAR-PUB-07/015, SLAC-PUB-12417
#
#           categories                                            license  \
# 0      math.CO cs.CG  http://arxiv.org/licenses/nonexclusive-distrib...
# 1  cond-mat.mtrl-sci  http://arxiv.org/licenses/nonexclusive-distrib...
# 2            math.CO                                                NaN
# 3            math.NT                                                NaN
# 4             hep-ex                                                NaN
#
#                                             abstract  \
# 0    We describe a new algorithm, the $(k,\ell)$-...
# 1    A general formulation was developed to repre...
# 2    Partial cubes are isometric subgraphs of hyp...
# 3    Serre obtained the p-adic limit of the integ...
# 4    The shape of the hadronic form factor f+(q2)...
#
#                                             versions update_date  \
# 0  [{'created': 'Sat, 31 Mar 2007 02:26:18 GMT', ...  2008-12-13
# 1  [{'created': 'Sat, 31 Mar 2007 04:47:20 GMT', ...  2009-02-05
# 2  [{'created': 'Sat, 31 Mar 2007 05:10:16 GMT', ...  2007-05-23
# 3  [{'created': 'Sat, 31 Mar 2007 06:21:49 GMT', ...  2008-05-26
# 4  [{'created': 'Sat, 31 Mar 2007 09:49:10 GMT', ...  2015-06-30
#
#                                     authors_parsed
# 0         [[Streinu, Ileana, ], [Theran, Louis, ]]
# 1                           [[Swift, Damian C., ]]
# 2                        [[Ovchinnikov, Sergei, ]]
# 3           [[Choi, Dohoon, ], [Choie, YoungJu, ]]
# 4  [[The BABAR Collaboration, , ], [Aubert, B., ]]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300851 entries, 0 to 300850
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              300851 non-null  str
#  1   submitter       299375 non-null  str
#  2   authors         300851 non-null  str
#  3   title           300851 non-null  str
#  4   comments        219015 non-null  str
#  5   journal-ref     93831 non-null   str
#  6   doi             130283 non-null  str
#  7   report-no       19074 non-null   str
#  8   categories      300851 non-null  str
#  9   license         255668 non-null  str
#  10  abstract        300851 non-null  str
#  11  versions        300851 non-null  object
#  12  update_date     300851 non-null  str
#  13  authors_parsed  300851 non-null  object
# dtypes: object(2), str(12)
# memory usage: 407.5+ MB

# %%
abstracts_parsed = prepare_abstracts_for_nlp(df)

# %%
abstracts_parsed.head()
# Out:
#           id                                       abstract_raw  \
# 0  0704.0002    We describe a new algorithm, the $(k,\ell)$-...
# 1  0704.0008    A general formulation was developed to repre...
# 2  0704.0010    Partial cubes are isometric subgraphs of hyp...
# 3  0704.0013    Serre obtained the p-adic limit of the integ...
# 4  0704.0020    The shape of the hadronic form factor f+(q2)...
#
#                                abstract_tokens_clean  \
# 0  [describe, new, algorithm, pebble, game, color...
# 1  [general, formulation, develop, represent, mat...
# 2  [partial, cube, isometric, subgraphs, hypercub...
# 3  [serre, obtain, padic, limit, integral, fourie...
# 4  [shape, hadronic, form, factor, decay, nue, me...
#
#                                       abstract_clean  abstract_token_count
# 0  describe new algorithm pebble game color obtai...                    69
# 1  general formulation develop represent material...                    78
# 2  partial cube isometric subgraphs hypercubes st...                    60
# 3  serre obtain padic limit integral fourier coef...                    57
# 4  shape hadronic form factor decay nue measure i...                    42

# %%
abstracts_parsed.to_parquet('./abstracts_parsed.parquet')
